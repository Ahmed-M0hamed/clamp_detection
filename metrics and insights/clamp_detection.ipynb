# %% [markdown]
# # Upload the data
#
#
# ---
#
# upload the dataset from Roboflow

# %%
import os
HOME = os.getcwd()

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.5/112.6 GB disk)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="bgZz4XsPKrewZX7Qhbab")
project = rf.workspace("ahmeds-workspace-slwao").project("clamp_detection-0fjwm")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # The Model

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11m model
model = YOLO("yolo11m.pt")

# Train the model
results = model.train(data="clamp_detection-2/data.yaml", epochs=10, imgsz=640  )
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# # Predict

# %%
import cv2

# %%
# Input and output video paths
input_video = "/content/Task.mp4"
output_video = "/content/predict.mp4"

# Open input video
cap = cv2.VideoCapture(input_video)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_video, fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()

    if not ret:
        break

    results = model(frame  , conf =.1 , iou=0 )

    annotated_frame = results[0].plot()

    out.write(annotated_frame)


    # Press q to quit early
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 clamps, 24.0ms
# Speed: 3.5ms preprocess, 24.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 clamps, 23.9ms
# Speed: 3.7ms preprocess, 23.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 clamps, 24.8ms
# Speed: 3.7ms preprocess, 24.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 clamps, 23.9ms
# Speed: 3.4ms preprocess, 23.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 clamps, 24.0ms
# Speed: 3.4ms preprocess, 24.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 clamps, 23.9ms
# Speed: 3.1ms preprocess, 23.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 clamps, 20.4ms
# Speed: 3.0ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 clamps, 20.4ms
# ...
